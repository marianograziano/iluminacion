    "LISTA DE PRECIOS 12 DE JULIO DE 2023        NRO. 43",
    "LISTA DE PRECIOS 13 DE AGOSTO DE 2023       NRO. 44",
    "LISTA DE PRECIOS 14 DE SEPTIEMBRE DE 2023   NRO. 45",
    "LISTA DE PRECIOS 15 DE OCTUBRE DE 2023      NRO. 46",
    "LISTA DE PRECIOS 16 DE NOVIEMBRE DE 2023    NRO. 47",
    "LISTA DE PRECIOS 17 DE DICIEMBRE DE 2023    NRO. 48",
    "LISTA DE PRECIOS 18 DE ENERO DE 2024        NRO. 49",
    "LISTA DE PRECIOS 19 DE FEBRERO DE 2024      NRO. 50",
]


def extraer_fecha(texto):
    # Definimos el patrón de búsqueda con expresiones regulares para encontrar la fecha
    patron = r'(\d{1,2}) DE (\w+) DE (\d{4})'
    # Buscamos en el texto el patrón definido
    match = re.search(patron, texto)
    if match:
        # Extraemos los componentes de la fecha
        dia, mes, ano = match.groups()
        # Convertimos el mes de texto a número
        meses = ['ENERO', 'FEBRERO', 'MARZO', 'ABRIL', 'MAYO', 'JUNIO',
                 'JULIO', 'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE', 'NOVIEMBRE', 'DICIEMBRE']
        mes_numero = meses.index(mes.upper()) + 1
        # Creamos un objeto datetime con la fecha extraída
        fecha = datetime(int(ano), mes_numero, int(dia))
        return fecha
    else:
        return None

for item in lista_de_precios:
    fecha = extraer_fecha(item)
    if fecha:
        print(item + ' ' + str(fecha))
    else:
        print(item)
# Out:
# LISTA DE PRECIOS 01 DE ENERO DE 2020          NRO. 1 2020-01-01 00:00:00
# LISTA DE PRECIOS 02 DE FEBRERO DE 2020      NRO. 2 2020-02-02 00:00:00
# LISTA DE PRECIOS 03 DE MARZO DE 2020        NRO. 3 2020-03-03 00:00:00
# LISTA DE PRECIOS 04 DE ABRIL DE 2020        NRO. 4 2020-04-04 00:00:00
# LISTA DE PRECIOS 05 DE MAYO DE 2020         NRO. 5 2020-05-05 00:00:00
# LISTA DE PRECIOS 06 DE JUNIO DE 2020        NRO. 6 2020-06-06 00:00:00
# LISTA DE PRECIOS 07 DE JULIO DE 2020        NRO. 7 2020-07-07 00:00:00
# LISTA DE PRECIOS 08 DE AGOSTO DE 2020       NRO. 8 2020-08-08 00:00:00
# LISTA DE PRECIOS 09 DE SEPTIEMBRE DE 2020   NRO. 9 2020-09-09 00:00:00
# LISTA DE PRECIOS 10 DE OCTUBRE DE 2020      NRO. 10 2020-10-10 00:00:00
# LISTA DE PRECIOS 11 DE NOVIEMBRE DE 2020    NRO. 11 2020-11-11 00:00:00
# LISTA DE PRECIOS 12 DE DICIEMBRE DE 2020    NRO. 12 2020-12-12 00:00:00
# LISTA DE PRECIOS 13 DE ENERO DE 2021        NRO. 13 2021-01-13 00:00:00
# ...

# %%
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument '/home/mgraziano/.local/share/jupyter/runtime/kernel-v2-2309377CO3ldOIOyP16.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File ~/dev/anaconda3/lib/python3.10/argparse.py:1859, in ArgumentParser.parse_known_args(self, args, namespace)
#    1858 try:
# -> 1859     namespace, args = self._parse_known_args(args, namespace)
#    1860 except ArgumentError:
#
# File ~/dev/anaconda3/lib/python3.10/argparse.py:2072, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2071     # consume the next optional and any arguments for it
# -> 2072     start_index = consume_optional(start_index)
# ...
